# %%
from dotenv import load_dotenv
import os
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph, START,END
from typing import TypedDict

# %%
# Load .env file
load_dotenv()

# Get the API key from environment
api_key = os.getenv("OPENAI-API")

# %%
model = ChatOpenAI(
    model="gpt-4o-mini",  
    openai_api_key=api_key
)

# %%
# create state 

class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    title = state['title']

    prompt = f"Generate a detailed outline for a blog on the title - {title}"

    outline = model.invoke(prompt).content

    print(outline)

    state['outline'] = outline

    return state

# %%
def create_content(state: BlogState) -> BlogState:
    title = state['title']
    outline = state['outline']

    prompt = f"Write a detailed blog on the title - {title} using the outline \n {outline}"

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
# create graph
graph = StateGraph(BlogState)

# add nodes

graph.add_node("create_outline", create_outline)
graph.add_node("create_content", create_content)

# add edges

graph.add_edge(START, "create_outline")
graph.add_edge("create_outline", "create_content")
graph.add_edge("create_content",END)
# graph.add_edge("create_outline",END)


workflow = graph.compile()

# %%
initial_state = {"title" : "Rise of AI in India"} 

# final_State = {}

final_State = workflow.invoke(initial_state)
    

# print(final_State)
# Out:
# # Blog Outline: Rise of AI in India
#
# ## I. Introduction
#    A. Definition of Artificial Intelligence (AI)
#    B. Overview of AI's significance in the modern world
#    C. Purpose and scope of the blog: to explore the rise of AI in India and its implications
#
# ## II. Historical Context
#    A. Early beginnings of AI in India
#       1. Academic research and development in the 1980s and 1990s
#       2. Initial government initiatives and policies
#    B. The growth of the IT sector and its role in AI development
#    C. Significant milestones in AI evolution in India
#
# ## III. Current Landscape of AI in India
#    A. Key players in the AI ecosystem
#       1. Government initiatives: Digital India, AI for All
#       2. Major tech companies (e.g., TCS, Infosys, Wipro, and startups)
#       3. Academic and research institutions (e.g., IITs, IISc)
#    B. AI start-up ecosystem
#       1. Rise of AI-focused startups
#       2. Major investment trends and funding
#
# ## IV. Sectors Transforming with AI
#    A. Healthcare
#       1. AI applications in diagnostics and patient care
#       2. Innovations in telemedicine and health monitoring
#    B. Agriculture
#       1. AI-driven analytics for crop management
#       2. Use of drones and robotics in farming
#    C. Finance
#       1. Fraud detection and risk assessment using AI
#       2. Personal finance management AI tools
#    D. Transportation
#       1. Development of autonomous vehicles
#       2. AI in traffic management and logistics
#    E. Education
#       1. Personalized learning experiences through AI
#       2. AI in administrative automation
#
# ## V. Challenges in AI Implementation
#    A. Infrastructure limitations
#    B. Data privacy and security issues
#    C. Skill gap and workforce readiness
#    D. Ethical concerns surrounding AI usage
#    E. Regulation and policy hurdles
#
# ## VI. Government Initiatives and Support
#    A. National Strategy for Artificial Intelligence
#    B. Investments in research and development
#    C. Collaborations with private sector and international partners
#    D. Skill development programs for AI talent
#
# ## VII. The Role of Academia and Research Institutions
#    A. Contributions of universities in AI research
#    B. Collaborations between academia and industry
#    C. Notable projects and innovations originating from Indian research labs
#
# ## VIII. Future Trends and Predictions
#    A. Expected growth of the AI market in India
#    B. Emerging technologies and their potential impact (e.g., machine learning, deep learning, NLP)
#    C. The role of AI in driving economic growth and job creation
#    D. Predictions for AI's influence on society and various industries
#
# ## IX. Conclusion
#    A. Summary of key points
#    B. The importance of embracing AI for India's progress
#    C. Call to action for stakeholders—government, industry, and educational institutions—to foster a collaborative AI ecosystem
#
# ## X. Additional Resources
#    A. Links to reports and papers on AI in India
#    B. Suggested books and articles for further reading
#    C. Contact information for readers interested in discussion or inquiries
#
# This outline is structured to provide a comprehensive understanding of the rise of AI in India, covering historical, current, and future perspectives, while addressing challenges and government support initiatives.

# %%
print(final_State)
# Out:
# {'title': 'Rise of AI in India', 'outline': "# Blog Outline: Rise of AI in India\n\n## I. Introduction\n   A. Definition of Artificial Intelligence (AI)\n   B. Overview of AI's significance in the modern world\n   C. Purpose and scope of the blog: to explore the rise of AI in India and its implications\n\n## II. Historical Context\n   A. Early beginnings of AI in India\n      1. Academic research and development in the 1980s and 1990s\n      2. Initial government initiatives and policies\n   B. The growth of the IT sector and its role in AI development\n   C. Significant milestones in AI evolution in India\n\n## III. Current Landscape of AI in India\n   A. Key players in the AI ecosystem\n      1. Government initiatives: Digital India, AI for All\n      2. Major tech companies (e.g., TCS, Infosys, Wipro, and startups)\n      3. Academic and research institutions (e.g., IITs, IISc)\n   B. AI start-up ecosystem\n      1. Rise of AI-focused startups\n      2. Major investment trends and funding\n\n## IV. Sectors Transforming with AI\n   A. Healthcare\n      1. AI applications in diagnostics and patient care\n      2. Innovations in telemedicine and health monitoring\n   B. Agriculture\n      1. AI-driven analytics for crop management\n      2. Use of drones and robotics in farming\n   C. Finance\n      1. Fraud detection and risk assessment using AI\n      2. Personal finance management AI tools\n   D. Transportation\n      1. Development of autonomous vehicles\n      2. AI in traffic management and logistics\n   E. Education\n      1. Personalized learning experiences through AI\n      2. AI in administrative automation\n\n## V. Challenges in AI Implementation\n   A. Infrastructure limitations\n   B. Data privacy and security issues\n   C. Skill gap and workforce readiness\n   D. Ethical concerns surrounding AI usage\n   E. Regulation and policy hurdles\n\n## VI. Government Initiatives and Support\n   A. National Strategy for Artificial Intelligence\n   B. Investments in research and development\n   C. Collaborations with private sector and international partners\n   D. Skill development programs for AI talent\n\n## VII. The Role of Academia and Research Institutions\n   A. Contributions of universities in AI research\n   B. Collaborations between academia and industry\n   C. Notable projects and innovations originating from Indian research labs\n\n## VIII. Future Trends and Predictions\n   A. Expected growth of the AI market in India\n   B. Emerging technologies and their potential impact (e.g., machine learning, deep learning, NLP)\n   C. The role of AI in driving economic growth and job creation\n   D. Predictions for AI's influence on society and various industries\n\n## IX. Conclusion\n   A. Summary of key points\n   B. The importance of embracing AI for India's progress\n   C. Call to action for stakeholders—government, industry, and educational institutions—to foster a collaborative AI ecosystem\n\n## X. Additional Resources\n   A. Links to reports and papers on AI in India\n   B. Suggested books and articles for further reading\n   C. Contact information for readers interested in discussion or inquiries\n\nThis outline is structured to provide a comprehensive understanding of the rise of AI in India, covering historical, current, and future perspectives, while addressing challenges and government support initiatives.", 'content': '# Rise of AI in India\n\n## I. Introduction\n\nArtificial Intelligence (AI) is essentially the simulation of human intelligence processes by machines, especially computer systems. These processes include learning, reasoning, problem-solving, perception, language understanding, and others. Its significance in the modern world cannot be overstated; AI has transformed industries, reshaped job markets, and enhanced consumer experiences, contributing to innovations that streamline operations and improve efficiency across sectors.\n\nThis blog aims to explore the rise of AI in India—tracking its hist ...

# %%
print(final_State['outline'])
# Out:
# # Blog Outline: Rise of AI in India
#
# ## I. Introduction
#    A. Definition of Artificial Intelligence (AI)
#    B. Overview of AI's significance in the modern world
#    C. Purpose and scope of the blog: to explore the rise of AI in India and its implications
#
# ## II. Historical Context
#    A. Early beginnings of AI in India
#       1. Academic research and development in the 1980s and 1990s
#       2. Initial government initiatives and policies
#    B. The growth of the IT sector and its role in AI development
#    C. Significant milestones in AI evolution in India
#
# ## III. Current Landscape of AI in India
#    A. Key players in the AI ecosystem
#       1. Government initiatives: Digital India, AI for All
#       2. Major tech companies (e.g., TCS, Infosys, Wipro, and startups)
#       3. Academic and research institutions (e.g., IITs, IISc)
#    B. AI start-up ecosystem
#       1. Rise of AI-focused startups
#       2. Major investment trends and funding
#
# ## IV. Sectors Transforming with AI
#    A. Healthcare
#       1. AI applications in diagnostics and patient care
#       2. Innovations in telemedicine and health monitoring
#    B. Agriculture
#       1. AI-driven analytics for crop management
#       2. Use of drones and robotics in farming
#    C. Finance
#       1. Fraud detection and risk assessment using AI
#       2. Personal finance management AI tools
#    D. Transportation
#       1. Development of autonomous vehicles
#       2. AI in traffic management and logistics
#    E. Education
#       1. Personalized learning experiences through AI
#       2. AI in administrative automation
#
# ## V. Challenges in AI Implementation
#    A. Infrastructure limitations
#    B. Data privacy and security issues
#    C. Skill gap and workforce readiness
#    D. Ethical concerns surrounding AI usage
#    E. Regulation and policy hurdles
#
# ## VI. Government Initiatives and Support
#    A. National Strategy for Artificial Intelligence
#    B. Investments in research and development
#    C. Collaborations with private sector and international partners
#    D. Skill development programs for AI talent
#
# ## VII. The Role of Academia and Research Institutions
#    A. Contributions of universities in AI research
#    B. Collaborations between academia and industry
#    C. Notable projects and innovations originating from Indian research labs
#
# ## VIII. Future Trends and Predictions
#    A. Expected growth of the AI market in India
#    B. Emerging technologies and their potential impact (e.g., machine learning, deep learning, NLP)
#    C. The role of AI in driving economic growth and job creation
#    D. Predictions for AI's influence on society and various industries
#
# ## IX. Conclusion
#    A. Summary of key points
#    B. The importance of embracing AI for India's progress
#    C. Call to action for stakeholders—government, industry, and educational institutions—to foster a collaborative AI ecosystem
#
# ## X. Additional Resources
#    A. Links to reports and papers on AI in India
#    B. Suggested books and articles for further reading
#    C. Contact information for readers interested in discussion or inquiries
#
# This outline is structured to provide a comprehensive understanding of the rise of AI in India, covering historical, current, and future perspectives, while addressing challenges and government support initiatives.

# %%
print(final_State['content'])
# Out:
# # Rise of AI in India
#
# ## I. Introduction
#
# Artificial Intelligence (AI) is essentially the simulation of human intelligence processes by machines, especially computer systems. These processes include learning, reasoning, problem-solving, perception, language understanding, and others. Its significance in the modern world cannot be overstated; AI has transformed industries, reshaped job markets, and enhanced consumer experiences, contributing to innovations that streamline operations and improve efficiency across sectors.
#
# This blog aims to explore the rise of AI in India—tracking its historical context, current landscape, sectoral transformations, and the challenges it faces. We will also delve into government initiatives, the role of academia, and future trends, painting a comprehensive picture of AI's impact on one of the world’s fastest-growing economies.
#
# ## II. Historical Context
#
# ### A. Early Beginnings of AI in India
#
# AI's roots in India trace back to the academic research and development of the 1980s and 1990s. Pioneering institutions such as the Indian Institute of Technology (IIT), Indian Institute of Science (IISc), and various private universities commenced research primarily focused on theoretical aspects of machine reasoning and natural language processing. The establishment of these research hubs laid the foundation for what would become a vibrant AI landscape.
#
# Initial government initiatives in this era included the formation of the Department of Information Technology and funding for various AI projects through national research grants. These early endeavors, although limited, instigated a slow but steady interest in AI research and applications.
#
# ### B. The Growth of the IT Sector and Its Role in AI Development
#
# The explosion of the Information Technology (IT) sector in the early 2000s provided a massive boost to AI in India. The IT boom paved the way for outsourcing, global collaboration, and job creation, establishing a ripe environment for innovation in AI. Companies began leveraging AI-driven solutions to enhance efficiencies and optimize delivery processes.
#
# ### C. Significant Milestones in AI Evolution in India
#
# Milestones such as the establishment of AI research centers, government policies supporting technology adoption, and collaboration between academia and industry were crucial. By the mid-2010s, nations increasingly began recognizing AI’s potential, with India positioning itself as a significant contributor to global AI research and development.
#
# ## III. Current Landscape of AI in India
#
# ### A. Key Players in the AI Ecosystem
#
# #### 1. Government Initiatives: Digital India, AI for All
#
# The Indian government has launched several initiatives, including Digital India and AI for All, aimed at harnessing AI technology to improve access to services and boost economic growth. These initiatives seek to promote AI education and drive research and innovation across sectors.
#
# #### 2. Major Tech Companies
#
# Tech giants—including TCS, Infosys, Wipro, and start-ups like Zoho and Freshworks—are actively integrating AI into their operations and offerings. TCS, for instance, employs AI-driven analytics to enhance client solutions, while start-ups are innovating with niche applications in various domains.
#
# #### 3. Academic and Research Institutions
#
# Institutions such as the IITs and IISc have contributed significantly to AI research, producing some of the brightest minds and groundbreaking innovations. Collaborative projects between academia and industry have yielded impactful results, enhancing the applicability of AI in real-world scenarios.
#
# ### B. AI Start-up Ecosystem
#
# The AI start-up ecosystem in India is burgeoning. Start-ups like Uncanny Vision and Niramai are leveraging AI in sectors such as security, health diagnostics, and personalized consumer experiences. Major investment trends show a surge in funding for AI-focused companies, driven by both domestic and international investors eyeing the potential for exponential growth.
#
# ## IV. Sectors Transforming with AI
#
# ### A. Healthcare
#
# AI applications are revolutionizing the healthcare sector in India. Through advanced diagnostics, machine learning algorithms analyze medical data to assist in patient care and disease prevention. Innovations in telemedicine and health monitoring also enhance accessibility to medical services, especially in rural areas.
#
# ### B. Agriculture
#
# AI-driven analytics provide farmers with actionable insights through crop management technologies, improving yield and minimizing waste. The use of drones and robotics has introduced efficiency to farming processes, enabling precision agriculture and more effective resource utilization.
#
# ### C. Finance
#
# AI is reshaping the finance sector with applications in fraud detection, risk assessment, and customer service automation. Personal finance management tools powered by AI are helping consumers make informed decisions regarding investment and budgeting.
#
# ### D. Transportation
#
# The development of autonomous vehicles in India is no longer a futuristic concept. AI is also used in traffic management systems, improving logistics and reducing congestion through smart routing systems.
#
# ### E. Education
#
# AI is redefining education through personalized learning experiences, allowing for tailored tutoring and assessments based on individual students’ needs. Administrative automation via AI tools has streamlined operations within educational institutions, freeing up resources for more critical educational endeavors.
#
# ## V. Challenges in AI Implementation
#
# Despite the rapid growth of AI technologies, challenges persist:
#
# ### A. Infrastructure Limitations
#
# AI implementation often requires robust infrastructure, which varies significantly across urban and rural areas. Limited internet access and high costs can hinder the adoption of AI technologies, particularly in underserved communities.
#
# ### B. Data Privacy and Security Issues
#
# As data is a core component of AI, issues surrounding data privacy, security, and ethical usage are paramount. The Indian government and private sectors must establish comprehensive regulations to safeguard personal information.
#
# ### C. Skill Gap and Workforce Readiness
#
# There is a substantial skill gap in the tech workforce concerning AI. As industries evolve and AI becomes more prevalent, reskilling and upskilling efforts must ramp up to ensure the workforce can meet emerging demands.
#
# ### D. Ethical Concerns Surrounding AI Usage
#
# Ethical implications of AI—including bias in algorithms and decision-making processes—pose significant concerns that require vigilant oversight and regulation to protect users and promote fairness.
#
# ### E. Regulation and Policy Hurdles
#
# Creasing effective regulations and policies toward AI innovation is essential to prevent misuse while fostering an environment conducive to progress. Balancing innovation with ethics will be critical moving forward.
#
# ## VI. Government Initiatives and Support
#
# The Indian government has committed to fostering AI development through initiatives such as the National Strategy for Artificial Intelligence, which aims to position India as a global leader in AI. Investments in research and development are being made, alongside collaborations with private sectors and international partners. Skill development programs aimed at nurturing AI talent are essential to maintaining a competitive edge.
#
# ## VII. The Role of Academia and Research Institutions
#
# Indian universities and research institutions have contributed substantially to AI breakthroughs. Collaborations with industries yield transformative projects that often lead to real-world applications. Institutions actively foster innovation, evidenced by collaborations researching autonomous systems and AI applications in healthcare.
#
# ## VIII. Future Trends and Predictions
#
# The growth trajectory of the AI market in India is promising, with estimates predicting it will significantly surpass existing forecasts. Emerging technologies in machine learning, deep learning, and natural language processing are likely to shape the future landscape. As AI drives economic growth and job creation, its influence will permeate various sectors, reshaping customer experiences and operational efficiencies.
#
# ## IX. Conclusion
#
# The rise of AI in India marks a significant technological evolution that can propel the nation toward a prosperous future. The urgency for embracing AI is evident in its potential to enhance productivity and drive innovative solutions across sectors. A collaborative approach involving government, industry, and educational institutions is vital to building a robust AI ecosystem that fosters innovation while ensuring ethical practices and equitable access.
#
# ## X. Additional Resources
#
# - **Links to Reports**:
#    - NITI Aayog’s discussion papers on AI in India
#    - Reports from McKinsey on the economic impact of AI
#
# - **Suggested Reading**:
#    - "Artificial Intelligence: A Guide to Intelligent Systems" by Michael Negnevitsky
#    - "Life 3.0: Being Human in the Age of Artificial Intelligence" by Max Tegmark
#
# - **Contact Information**:
#    - Interested readers can reach out to discuss insights or inquiries related to AI in India at [your email address].
#
# The rise of AI in India represents not just a technological advancement but a cultural shift within society, potentially leading to improvements in quality of life and economic resilience in the face of global challenges.
